# %% [markdown]
# PDFの表を読み込む
# https://qiita.com/konitech913/items/4ef70e1f7753c824b40f
# https://www.youtube.com/watch?v=W-2kTy96yAo&t=408s

# %%
import pandas as pd
import tabula

# %%
# !java version
# Out:
# �G���[: ���C���E�N���Xversion�����o�����у��[�h�ł��܂����ł���
# ����: java.lang.ClassNotFoundException: version

# %% [markdown]
# javaがインストールされていない場合、javaのインストールが必要
# インストール方法: https://rightcode.co.jp/blog/become-engineer/java-install

# %%
tabula.environment_info()
# Out:
# Python version:
#     3.7.8 (tags/v3.7.8:4b47a5b6ba, Jun 28 2020, 08:53:46) [MSC v.1916 64 bit (AMD64)]
# Java version:
#     java version "11.0.12" 2021-07-20 LTS
# Java(TM) SE Runtime Environment 18.9 (build 11.0.12+8-LTS-237)
# Java HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.12+8-LTS-237, mixed mode)
# tabula-py version: 2.2.0
# platform: Windows-10-10.0.18362-SP0
# uname:
#     uname_result(system='Windows', node='ALIENWARE', release='10', version='10.0.18362', machine='AMD64', processor='Intel64 Family 6 Model 158 Stepping 10, GenuineIntel')
# linux_distribution: ('', '', '')
# mac_ver: ('', ('', '', ''), '')

# %%
pdf_path="https://www.mhlw.go.jp/content/10906000/000618483.pdf"
dfs = tabula.read_pdf(pdf_path,stream=True)
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: 8月 10, 2021 4:09:09 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 8月 10, 2021 4:09:09 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 8月 10, 2021 4:09:09 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 8月 10, 2021 4:09:10 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 8月 10, 2021 4:09:10 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# 8月 10, 2021 4:09:10 午後 org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# ...

# %%
print(len(dfs))
# Out:
# 1

# %%
dfs[0]
# Out:
#    都道府県名  陽性者数     検査人数 備考  Unnamed: 0 都道府県名.1 陽性者数.1      検査人数 備考.1
# 0    北海道   182        2096         NaN     滋賀県      8            232
# 1    青森県     8         137         NaN     京都府     71           1178
# 2    岩手県     0          59         NaN     大阪府    279  630 ※1 3/30時点
# 3    宮城県     7  208 3/30時点         NaN     兵庫県    161           2462
# 4    秋田県     6         261         NaN     奈良県     15            314
# 5    山形県     1         222         NaN    和歌山県     18           1479
# 6    福島県     6         204         NaN     鳥取県      0            182
# 7    茨城県    24        1028         NaN     島根県      0            136
# 8    栃木県    14         456         NaN     岡山県      4            321
# 9    群馬県    20         289         NaN     広島県      6            960
# 10   埼玉県   101        1293         NaN     山口県      6            287
# 11   千葉県   175      527 ※1         NaN     徳島県      3            144
# 12   東京都   593        3027         NaN     香川県      2     243 3/30時点
# ...

# %%
file_path="data.pdf"
dfs = tabula.read_pdf(file_path,stream=True, pages="all")

# %%
len(dfs)
# Out:
# 4

# %%
dfs[0].head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
dfs[1].head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dfs[2].head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0         145           6.7          3.3           5.7          2.5  virginica
# 1         146           6.7          3.0           5.2          2.3  virginica
# 2         147           6.3          2.5           5.0          1.9  virginica
# 3         148           6.5          3.0           5.2          2.0  virginica
# 4         149           6.2          3.4           5.4          2.3  virginica

# %%
dfs[3].head()
# Out:
#     len supp  dose
# 0   4.2   VC   0.5
# 1  11.5   VC   0.5
# 2   7.3   VC   0.5
# 3   5.8   VC   0.5
# 4   6.4   VC   0.5
